# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/dynamics
# !git clone https://github.com/HuangYin0514/dynamics.git
# %cd /kaggle/working/dynamics/PINN_Burgers

import sys
sys.path.append('/kaggle/input/pylib-pydoe/MySitePackages')
# Out:
# /kaggle/working
# Cloning into 'dynamics'...
# remote: Enumerating objects: 2123, done.
# remote: Counting objects: 100% (2123/2123), done.
# remote: Compressing objects: 100% (1491/1491), done.
# remote: Total 2123 (delta 966), reused 1742 (delta 588), pack-reused 0
# Receiving objects: 100% (2123/2123), 63.52 MiB | 21.57 MiB/s, done.
# Resolving deltas: 100% (966/966), done.
# /kaggle/working/dynamics/PINN_Burgers

# %%
# %%time

# !python main.py
# Out:
# Adam	epoch:0	loss:0.26642
# LBFGS	 epoch:0	 loss:0.04804
# LBFGS	 epoch:200	 loss:0.0082178
# LBFGS	 epoch:400	 loss:0.0020972
# LBFGS	 epoch:600	 loss:0.0008005
# LBFGS	 epoch:800	 loss:0.00041916
# LBFGS	 epoch:1000	 loss:0.00029231
# LBFGS	 epoch:1200	 loss:0.00018508
# LBFGS	 epoch:1400	 loss:0.00012657
# LBFGS	 epoch:1600	 loss:9.5467e-05
# LBFGS	 epoch:1800	 loss:7.3337e-05
# LBFGS	 epoch:2000	 loss:5.4928e-05
# LBFGS	 epoch:2200	 loss:4.3906e-05
# LBFGS	 epoch:2400	 loss:3.672e-05
# LBFGS	 epoch:2600	 loss:3.1102e-05
# LBFGS	 epoch:2800	 loss:2.6639e-05
# LBFGS	 epoch:3000	 loss:2.3721e-05
# LBFGS	 epoch:3200	 loss:2.0227e-05
# LBFGS	 epoch:3400	 loss:1.8101e-05
# LBFGS	 epoch:3600	 loss:1.5293e-05
# LBFGS	 epoch:3800	 loss:1.3324e-05
# LBFGS	 epoch:4000	 loss:1.1757e-05
# LBFGS	 epoch:4200	 loss:1.0513e-05
# LBFGS	 epoch:4400	 loss:9.4095e-06
# LBFGS	 epoch:4600	 loss:8.2735e-06
# LBFGS	 epoch:4800	 loss:7.3916e-06
# done
# CPU times: user 1.68 s, sys: 255 ms, total: 1.94 s
# Wall time: 1min 50s

# %%
# !python predict.py

# !python plot_result.py
# Out:
# Mean relative L2 error of s: 1.90e-03
# done.

# %%
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

if __name__ == '__main__':
    img = mpimg.imread("result/deeponet.png")
    plt.figure(figsize=(20,10))
    plt.imshow(img)
    plt.axis('off')
    plt.show()
