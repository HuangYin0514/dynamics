# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/dynamics
# !git clone https://github.com/HuangYin0514/dynamics.git
# %cd /kaggle/working/dynamics/PINN/burgers_v2_1
# %cd /kaggle/working/dynamics/DeepONet/burgers_v1_3

import sys
sys.path.append('/kaggle/input/pylib-pydoe/MySitePackages')
# Out:
# /kaggle/working
# Cloning into 'dynamics'...
# remote: Enumerating objects: 2313, done.
# remote: Counting objects: 100% (2313/2313), done.
# remote: Compressing objects: 100% (1622/1622), done.
# remote: Total 2313 (delta 1081), reused 1873 (delta 644), pack-reused 0
# Receiving objects: 100% (2313/2313), 64.61 MiB | 11.58 MiB/s, done.
# Resolving deltas: 100% (1081/1081), done.
# /kaggle/working/dynamics/DeepONet/burgers_v1_3

# %%
# %%time

# !python main.py
# Out:
# Adam	epoch:0	loss:0.514
# LBFGS	 epoch:0	 loss:0.1299
# LBFGS	 epoch:200	 loss:0.042088
# LBFGS	 epoch:400	 loss:0.006973
# LBFGS	 epoch:600	 loss:0.0026711
# LBFGS	 epoch:800	 loss:0.0013668
# LBFGS	 epoch:1000	 loss:0.00075353
# LBFGS	 epoch:1200	 loss:0.00048597
# LBFGS	 epoch:1400	 loss:0.00035301
# LBFGS	 epoch:1600	 loss:0.00026747
# LBFGS	 epoch:1800	 loss:0.00019491
# LBFGS	 epoch:2000	 loss:0.00014354
# LBFGS	 epoch:2200	 loss:0.0001099
# LBFGS	 epoch:2400	 loss:8.0484e-05
# LBFGS	 epoch:2600	 loss:6.1661e-05
# LBFGS	 epoch:2800	 loss:5.1175e-05
# LBFGS	 epoch:3000	 loss:4.1602e-05
# LBFGS	 epoch:3200	 loss:3.5374e-05
# LBFGS	 epoch:3400	 loss:3.0973e-05
# LBFGS	 epoch:3600	 loss:2.7124e-05
# LBFGS	 epoch:3800	 loss:2.3467e-05
# LBFGS	 epoch:4000	 loss:2.5621e-05
# LBFGS	 epoch:4200	 loss:1.8536e-05
# LBFGS	 epoch:4400	 loss:1.6451e-05
# LBFGS	 epoch:4600	 loss:1.4057e-05
# LBFGS	 epoch:4800	 loss:1.2861e-05
# done
# CPU times: user 2.28 s, sys: 312 ms, total: 2.59 s
# Wall time: 2min 15s

# %%
# !python predict.py

# !python plot_result.py
# Out:
# Mean relative L2 error of s: 1.11e-03
# done.

# %%
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

if __name__ == '__main__':
    img = mpimg.imread("result/deeponet.png")
    plt.figure(figsize=(20,10))
    plt.imshow(img)
    plt.axis('off')
    plt.show()
